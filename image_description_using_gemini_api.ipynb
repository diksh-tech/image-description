# %%
# Step 1: Install Gemini client library
# !pip install -q google-generativeai

# Step 2: Import and configure API
import google.generativeai as genai

# 🔑 Replace this with your actual API key from https://makersuite.google.com/app/apikey
genai.configure(api_key)

# Step 3: Load a model
model = genai.GenerativeModel("gemini-1.5-flash")

# Step 4: Load and show an image
from PIL import Image
import IPython.display as display

image_path = "/content/WhatsApp Image 2025-07-03 at 1.13.16 PM.jpeg"  # Change this to your image path
image = Image.open(image_path)
display.display(image)

# Step 5: Generate caption from image
response = model.generate_content(
    ["Describe the image in detail:", image],
    stream=False
)

# Step 6: Show the output
print("\nCaption Generated:\n")
print(response.text)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=171x166>
# Caption Generated:
#
# That's an image of a QR code.
#
#
# Here's a breakdown of the image:
#
# * **Central Feature:** A standard QR code dominates the center of the image. It's black and white, with the characteristic square pattern.
#
# * **Framing:** A simple, black square frame surrounds the QR code, providing visual definition.
#
# * **Text:** Above the QR code, the text "TO START YOUR PLOY POTENTIAL ASSESSMENT?" is visible.  The question mark suggests it's a call to action. There are also three asterisks ("***") to the upper right.
#
# * **Background:** The background is a light purple or lavender shade. There are some small, faint, irregularly placed dots near the bottom.
#
# ...
